# %%
import pandas as pd
#main file for finding insights

df = pd.read_csv("datasets/series-261225.csv")
print(df.head(10))
# Out:
#                Title  \
# 0               CDID
# 1  Source dataset ID
# 2            PreUnit
# 3               Unit
# 4       Release date
# 5       Next release
# 6    Important notes
# 7               1998
# 8               1999
# 9               2000
#
#   GBServTO: 70.2 - Management consulting services TOTAL (£m)
# 0                                               JQ3Q
# 1                                               IOS1
# 2                                                NaN
# 3                                                NaN
# 4                                         12-12-2025
# 5                                    15 January 2026
# 6                                                NaN
# 7                                                0.0
# 8                                                0.0
# 9                                            15963.8
