# %%
#All imports below.
import pandas as pd

# %%
#cleaning our first dataset, our management consulting
df = pd.read_csv("datasets/series-261225.csv", skiprows=8, header=None)
print(df.head(5))
# Out:
#       0        1
# 0  1998      0.0
# 1  1999      0.0
# 2  2000  15963.8
# 3  2001  18831.7
# 4  2002  18325.3
